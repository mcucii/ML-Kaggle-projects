# %% [markdown]
# <a href="https://colab.research.google.com/github/mcucii/ML-projects/blob/main/Garbage%20Classification/GarbageClassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import tensorflow as tf
from PIL import Image
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, array_to_img, load_img
from tensorflow.keras.layers import Input, Activation, Add, Dense, Conv2D, GlobalAveragePooling2D, MaxPooling2D, BatchNormalization, Dropout
from keras.models import Model
from keras.utils import plot_model
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from matplotlib.colors import LinearSegmentedColormap

from sklearn.metrics import classification_report, confusion_matrix
# https://www.kaggle.com/code/farzadnekouei/imbalanced-garbage-classification-resnet50

# %%
#data_dir = './data/Garbage classification/'
# os.listdir(data_dir)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_dir = '/content/drive/MyDrive/ML_projects/data/Garbage classification'

# %%
class_names = sorted(os.listdir(data_dir))
class_to_index = {name: i for i,name in enumerate(class_names)}

images = []
labels = []
class_names
# Out:
# ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

# %%
img_height = 128
img_width = 128

# %%
garbage_types = os.listdir(data_dir)

# %% [markdown]
# ### ANALYZE DATA:

# %%
for garbage_type in garbage_types:
    folder_path = os.path.join(data_dir, garbage_type)
    if os.path.isdir(folder_path) :
        img_files = [f for f in os.listdir(folder_path) if f.endswith(('jpg', 'jpeg'))]
        img_files = img_files[:7]

        fig, axs = plt.subplots(1,7, figsize=(15,2))

        for i, img_file in enumerate(img_files) :
            img_path = os.path.join(folder_path, img_file)
            with Image.open(img_path) as img:
                axs[i].imshow(img)
                axs[i].axis('off')
        plt.tight_layout()
        fig.suptitle(garbage_type)
        plt.show()

# %% [markdown]
# ### DATASET PREPARATION:

# %%
data = []

for garbage_type in garbage_types:
    folder_path = os.path.join(data_dir, garbage_type)
    for file in os.listdir(os.path.join(data_dir, garbage_type)):
        fp = folder_path + "/" + file
        data.append((fp, garbage_type))

df = pd.DataFrame(data, columns=['filepath', 'label'])
df.head()
# Out:
#                                             filepath  label
# 0  /content/drive/MyDrive/ML_projects/data/Garbag...  metal
# 1  /content/drive/MyDrive/ML_projects/data/Garbag...  metal
# 2  /content/drive/MyDrive/ML_projects/data/Garbag...  metal
# 3  /content/drive/MyDrive/ML_projects/data/Garbag...  metal
# 4  /content/drive/MyDrive/ML_projects/data/Garbag...  metal

# %% [markdown]
# ### DATA SPLIT

# %%
# startify - omogucava da trening i test skup imaju isti odnos klasa kao originalni skup
train_df, val_df = train_test_split(df, test_size=0.2, random_state=42, stratify=df['label'])
print(f"number of images in the training set: {len(train_df)}")
print(f"number of images in the validation set: {len(val_df)}")
# Out:
# number of images in the training set: 2021
# number of images in the validation set: 506

# %%
# Let's verify that the distributions in the training and validation sets closely mirror the overall distribution:
overall_distribution = df['label'].value_counts(normalize=True)*100
print("Overall distribution: ")
print(overall_distribution.round(2))

train_distribution = train_df['label'].value_counts(normalize=True)*100
print("Train distribution: ")
print(train_distribution.round(2))

val_distribution = val_df['label'].value_counts(normalize=True)*100
print("Validation distribution: ")
print(val_distribution.round(2))
# Out:
# Overall distribution:
# label
# paper        23.51
# glass        19.83
# plastic      19.07
# metal        16.22
# cardboard    15.95
# trash         5.42
# Name: proportion, dtype: float64
# Train distribution:
# label
# paper        23.50
# glass        19.84
# plastic      19.05
# metal        16.23
# cardboard    15.93
# trash         5.44
# Name: proportion, dtype: float64
# Validation distribution:
# label
# paper        23.52
# glass        19.76
# plastic      19.17
# metal        16.21
# cardboard    16.01
# trash         5.34
# Name: proportion, dtype: float64

# %%
# vidimo da zaista jesu sve distribucije manje vise dobre (podjednaka kolicina svakog tipa smeca u svakom skupu!)

# %% [markdown]
# ### Data Augmentation
# - technique used to expand training dataset to improve model's capacity to generalize and avoid overfitting

# %%
## ImageDataGenerator
train_datagen = ImageDataGenerator(
    rescale=1./255,                     # Normalize pixel values to [0,1]
    rotation_range=45,      # Randomly rotate the images by up to 45 degrees
    width_shift_range=0.15, # Randomly shift images horizontally by up to 15% of the width
    height_shift_range=0.15,
    zoom_range=0.15,
    horizontal_flip=True,
    vertical_flip=True,
    shear_range=0.05,
    brightness_range=[0.9, 1.1],
)

# %%
val_datagen = ImageDataGenerator(rescale=1./255)

# %% [markdown]
# ### Generating Batches
# - objasnjenje: https://studymachinelearning.com/keras-imagedatagenerator-with-flow_from_dataframe/

# %%
train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,                  # DataFrame containing training data
    x_col="filepath",                    # Column with paths to image files
    y_col="label",                       # Column with image labels
    target_size=(img_height, img_width),              # Resize all images to size of 384x384
    batch_size=32,                       # Number of images per batch
    class_mode='categorical',            # One-hot encode labels
    seed=42,                             # Seed for random number generator to ensure reproducibility
    shuffle=False                        # Data is not shuffled; order retained from DataFrame
)

val_generator=val_datagen.flow_from_dataframe(
    dataframe=val_df,
    x_col="filepath",
    y_col="label",
    target_size=(img_height, img_width),
    batch_size=32,
    class_mode='categorical',
    seed=42,
    shuffle=False
)
# Out:
# Found 2021 validated image filenames belonging to 6 classes.
# Found 506 validated image filenames belonging to 6 classes.

# %%
x_batch, y_batch = next(train_generator)

# %%
x_instance = x_batch[1]
y_instance = y_batch[1]

plt.imshow(x_instance)
plt.title(f"{y_instance}")
# Out:
# Text(0.5, 1.0, '[0. 1. 0. 0. 0. 0.]')

# %% [markdown]
# ### Addresing imbalance using class weights
# $weight(class) = \frac{total\_samples}{number\_of\_classes * samples\_in\_that\_class}$

# %%
class_labels = df['label'].unique()
class_labels
# Out:
# array(['metal', 'glass', 'cardboard', 'paper', 'plastic', 'trash'],
#       dtype=object)

# %%
# Compute class weights
weights = compute_class_weight(class_weight='balanced', classes=class_labels, y = train_df['label'])
weights
# Out:
# array([1.02693089, 0.83998337, 1.04606625, 0.70912281, 0.87489177,
#        3.06212121])

# %%
# Convert the computed weights to a dictionary for passing to model training
class_weights = dict(zip(train_generator.class_indices.values(), weights))
class_weights
# Out:
# {0: np.float64(1.026930894308943),
#  1: np.float64(0.8399833748960931),
#  2: np.float64(1.0460662525879918),
#  3: np.float64(0.7091228070175438),
#  4: np.float64(0.8748917748917749),
#  5: np.float64(3.062121212121212)}

# %% [markdown]
# ### ResNet50
# - the main feature of ResNet -> "skip" or "shortcut" connections
# - core component - Residual Block

# %%
def residual_block(X, kernel_size, filters, reduce=False, stride=2):
    # implement a residual block for resNet
    # arguments:
    # X - input tensor of shape (m, height, width, channels)
    # kernel_size - integer, kernel size of the middle CONV (convolutional) layer
    # filters - python list of integers defining the number of filters in the CONV layers
    # reduce - boolean, whether to reduce spatial dimensions and increase depth; if true, applies 1x1 CONV layer to the shortcut path
    # stride - integer, strides for the CONV layer
    #
    # returns:
    # X - output of the identity block, tensor of shape (height, width, channels)

    F1, F2, F3 = filters
    X_shortcut = X

    if reduce:
        # first component of the main path
        X = Conv2D(filters=F1, kernel_size=(1,1), strides=(stride, stride), padding='valid', kernel_initializer='he_normal')(X)
        X = BatchNormalization(axis=3)(X)
        X = Activation('relu')(X)

        X_shortcut = Conv2D(filters=F3, kernel_size=(1,1), strides=(stride, stride), padding='valid', kernel_initializer='he_normal')(X_shortcut)
        X_shortcut = BatchNormalization(axis=3)(X_shortcut)

    else:
        # first component of the main path
        X = Conv2D(filters=F1, kernel_size=(1,1), strides=(1, 1), padding='valid', kernel_initializer='he_normal')(X)
        X = BatchNormalization(axis=3)(X)
        X = Activation('relu')(X)

    # second component of the main path
    X = Conv2D(filters=F2, kernel_size=(kernel_size, kernel_size), strides=(1, 1), padding='same', kernel_initializer='he_normal')(X)
    X = BatchNormalization(axis=3)(X)
    X = Activation('relu')(X)

    # third component of the main path
    X = Conv2D(filters=F3, kernel_size=(1,1), strides=(1,1), padding='valid', kernel_initializer='he_normal')(X)
    X = BatchNormalization(axis=3)(X)

    ## FInal step: adding shortcut to main path X
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)

    return X

# %%
def ResNet50(input_shape, classes):
    X_input = Input(input_shape)

    # Block 1
    X = Conv2D(filters=64, kernel_size=(7,7), strides=(2,2), kernel_initializer='he_normal')(X_input)
    X = BatchNormalization(axis=3)(X)
    X = Activation('relu')(X)
    X = MaxPooling2D(pool_size=(3,3), strides=(2,2))(X)

    # Block 2
    X = residual_block(X, kernel_size=3, filters=[64,64,256], reduce=True, stride=1)
    X = residual_block(X, kernel_size=3, filters=[64,64,256])
    X = residual_block(X, kernel_size=3, filters=[64,64,256])

    # Block 3
    X = residual_block(X, kernel_size=3, filters=[128,128,512], reduce=True, stride=2)
    X = residual_block(X, kernel_size=3, filters=[128,128,512])
    X = residual_block(X, kernel_size=3, filters=[128,128,512])
    X = residual_block(X, kernel_size=3, filters=[128,128,512])

    # Block 4
    X = residual_block(X, kernel_size=3, filters=[256,256,1024], reduce=True, stride=2)
    X = residual_block(X, kernel_size=3, filters=[256,256,1024])
    X = residual_block(X, kernel_size=3, filters=[256,256,1024])
    X = residual_block(X, kernel_size=3, filters=[256,256,1024])
    X = residual_block(X, kernel_size=3, filters=[256,256,1024])
    X = residual_block(X, kernel_size=3, filters=[256,256,1024])

    # Block 5
    X = residual_block(X, kernel_size=3, filters=[512,512,2048], reduce=True, stride=2)
    X = residual_block(X, kernel_size=3, filters=[512,512,2048])
    X = residual_block(X, kernel_size=3, filters=[512,512,2048])


    X = GlobalAveragePooling2D()(X)
    X = Dense(classes, activation='softmax')(X)

    model = Model(inputs=X_input, outputs=X, name='ResNet50')

    return model

# %%
input_shape=(img_height, img_width,3) # defined in train gen
num_classes=6

resnet50_model = ResNet50(input_shape=input_shape, classes=num_classes)

# %%
resnet50_model.compile(optimizer='adam', loss='categorical_crossentropy' ,metrics=['accuracy'])

# %%
# Add ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=15, min_lr=0.00001)

# Add EarlyStopping callback
early_stopping = EarlyStopping(monitor='val_loss', mode='min', patience=50, restore_best_weights=True, verbose=1)

# %%
# num_epochs = 100
# history = resnet50_model.fit(train_generator,
#                              steps_per_epoch=len(train_generator),
#                              epochs=num_epochs,
#                              validation_data=val_generator,
#                              validation_steps=len(val_generator),
#                              class_weight=class_weights,
#                              callbacks=[reduce_lr, early_stopping])

# %% [markdown]
# ```Visualizing the learning curves```

# %%
def plot_learning_curves(history, start_epoch=5):
  df = pd.DataFrame(history.history)
  df = df.iloc[start_epoch-1:]
  #print(df)
  plt.figure(figsize=(15,5))

  # plot training and val loss
  plt.subplot(1,2,1)
  sns.lineplot(x=df.index, y=df['loss'], color='royalblue', label='train loss')
  sns.lineplot(x=df.index, y=df['val_loss'], color='orangered', label='validation loss')
  plt.title('Loss evaluation')

  # plot training and val acc
  plt.subplot(1,2,2)
  sns.lineplot(x=df.index, y=df['accuracy'], color='royalblue', label='train accuracy')
  sns.lineplot(x=df.index, y=df['val_accuracy'], color='orangered', label='validation accuracy')
  # moze i ovako
  # plt.plot(df.index, df['accuracy'], color='royalblue', label='train accuracy')
  # plt.plot(df.index, df['val_accuracy'], color='orangered', label='val accuracy')
  plt.title('Accuracy evaluation')

  plt.show()

# %% [markdown]
# Validation accuracy&loss fluctuates => overfitting!

# %%
def Modified_ResNet50(input_shape, classes):
  X_input = Input(input_shape)

  # stage 1
  X = Conv2D(64,(7,7),(2,2), kernel_initializer='he_normal')(X_input)
  X = BatchNormalization(axis=-1)(X)
  X = Activation(activation='relu')(X)
  X = MaxPooling2D((3,3), (2,2))(X)

  # stage 2
  X = residual_block(X, 3, [64,64,256], reduce=True, stride=1)
  X = residual_block(X, 3, [64,64,256])
  X = residual_block(X, 3, [64,64,256])

  # stage 3
  X = residual_block(X, 3, [128,128,512], reduce=True, stride=2)
  X = residual_block(X, 3, [128,128,512])
  X = residual_block(X, 3, [128,128,512])
  X = residual_block(X, 3, [128,128,512])

  # stage 4
  X = residual_block(X, 3, [256,256,1024], reduce=True, stride=2)
  X = residual_block(X, 3, [256,256,1024])
  X = residual_block(X, 3, [256,256,1024])
  X = residual_block(X, 3, [256,256,1024])
  X = residual_block(X, 3, [256,256,1024])
  X = residual_block(X, 3, [256,256,1024])

  # stage 5
  X = residual_block(X, 3, [512,512,2048], reduce=True, stride=2)
  X = residual_block(X, 3, [512,512,2048])
  X = residual_block(X, 3, [512,512,2048])

  X = GlobalAveragePooling2D()(X)

  # adding Dropout to prevent overfitting
  X = Dropout(0.5)(X)

  X = Dense(classes, activation='softmax')(X)

  model = Model(inputs=X_input, outputs=X, name='Modified_ResNet50')

  return model

# %%
input_shape=(img_height, img_width, 3)
num_classes = 6
modified_ResNet50 = Modified_ResNet50(input_shape=input_shape, classes=num_classes)

# %%
modified_ResNet50.compile(optimizer='adam', loss='categorical_crossentropy' ,metrics=['accuracy'])

# %%
reduce_lr =  ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=15, min_lr=0.00001)
early_stopping = EarlyStopping(monitor='val_loss', mode='min', patience=30, restore_best_weights=True, verbose=1)

# %%
num_epochs=100
history2 = modified_ResNet50.fit(train_generator,
                      steps_per_epoch=len(train_generator),
                      epochs=num_epochs,
                      validation_data=val_generator,
                      validation_steps=len(val_generator),
                      class_weight=class_weights,
                      callbacks=[reduce_lr, early_stopping])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 109s 776ms/step - accuracy: 0.2384 - loss: 3.1529 - val_accuracy: 0.1621 - val_loss: 13810.5605 - learning_rate: 0.0010
# Epoch 2/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 321ms/step - accuracy: 0.3852 - loss: 2.0157 - val_accuracy: 0.3300 - val_loss: 1.6761 - learning_rate: 0.0010
# Epoch 3/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 309ms/step - accuracy: 0.4565 - loss: 1.6499 - val_accuracy: 0.2174 - val_loss: 87.6645 - learning_rate: 0.0010
# Epoch 4/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 323ms/step - accuracy: 0.4415 - loss: 1.6294 - val_accuracy: 0.2213 - val_loss: 2.1525 - learning_rate: 0.0010
# Epoch 5/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 321ms/step - accuracy: 0.4914 - loss: 1.4383 - val_accuracy: 0.3498 - val_loss: 7.3411 - learning_rate: 0.0010
# Epoch 6/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 320ms/step - accuracy: 0.4945 - loss: 1.4745 - val_accuracy: 0.5178 - val_loss: 2.1045 - learning_rate: 0.0010
# Epoch 7/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 326ms/step - accuracy: 0.5058 - loss: 1.4254 - val_accuracy: 0.5198 - val_loss: 10.3020 - learning_rate: 0.0010
# Epoch 8/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 312ms/step - accuracy: 0.5007 - loss: 1.4014 - val_accuracy: 0.1581 - val_loss: 3.5431 - learning_rate: 0.0010
# Epoch 9/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 22s 344ms/step - accuracy: 0.4451 - loss: 1.4426 - val_accuracy: 0.2648 - val_loss: 20.9028 - learning_rate: 0.0010
# Epoch 10/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 312ms/step - accuracy: 0.4454 - loss: 1.6111 - val_accuracy: 0.2569 - val_loss: 27.0073 - learning_rate: 0.0010
# Epoch 11/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 317ms/step - accuracy: 0.3872 - loss: 1.5833 - val_accuracy: 0.4130 - val_loss: 11.7115 - learning_rate: 0.0010
# Epoch 12/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 311ms/step - accuracy: 0.5002 - loss: 1.2916 - val_accuracy: 0.4625 - val_loss: 3.3506 - learning_rate: 0.0010
# Epoch 13/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 328ms/step - accuracy: 0.4832 - loss: 1.2767 - val_accuracy: 0.5020 - val_loss: 2.3961 - learning_rate: 0.0010
# Epoch 14/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 321ms/step - accuracy: 0.5229 - loss: 1.1913 - val_accuracy: 0.4862 - val_loss: 1.5752 - learning_rate: 0.0010
# Epoch 15/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 324ms/step - accuracy: 0.5640 - loss: 1.1173 - val_accuracy: 0.5613 - val_loss: 1.0849 - learning_rate: 0.0010
# Epoch 16/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 311ms/step - accuracy: 0.5821 - loss: 1.0917 - val_accuracy: 0.0534 - val_loss: 89.1226 - learning_rate: 0.0010
# Epoch 17/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 320ms/step - accuracy: 0.4001 - loss: 1.6201 - val_accuracy: 0.1976 - val_loss: 4.0051 - learning_rate: 0.0010
# Epoch 18/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 313ms/step - accuracy: 0.4722 - loss: 1.3462 - val_accuracy: 0.4229 - val_loss: 1.7037 - learning_rate: 0.0010
# Epoch 19/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 322ms/step - accuracy: 0.5163 - loss: 1.2851 - val_accuracy: 0.4684 - val_loss: 1.3293 - learning_rate: 0.0010
# Epoch 20/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 314ms/step - accuracy: 0.5392 - loss: 1.2061 - val_accuracy: 0.5514 - val_loss: 1.2579 - learning_rate: 0.0010
# Epoch 21/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 326ms/step - accuracy: 0.5869 - loss: 1.1506 - val_accuracy: 0.3043 - val_loss: 1.9098 - learning_rate: 0.0010
# Epoch 22/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 334ms/step - accuracy: 0.4156 - loss: 1.6285 - val_accuracy: 0.2292 - val_loss: 2.2866 - learning_rate: 0.0010
# Epoch 23/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 40s 322ms/step - accuracy: 0.5019 - loss: 1.4115 - val_accuracy: 0.3854 - val_loss: 1.5938 - learning_rate: 0.0010
# Epoch 24/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 308ms/step - accuracy: 0.5423 - loss: 1.2544 - val_accuracy: 0.3676 - val_loss: 1.6187 - learning_rate: 0.0010
# Epoch 25/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 322ms/step - accuracy: 0.5417 - loss: 1.1927 - val_accuracy: 0.4328 - val_loss: 1.3655 - learning_rate: 0.0010
# Epoch 26/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 313ms/step - accuracy: 0.5765 - loss: 1.1599 - val_accuracy: 0.4170 - val_loss: 1.5901 - learning_rate: 0.0010
# Epoch 27/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 328ms/step - accuracy: 0.5495 - loss: 1.1880 - val_accuracy: 0.3597 - val_loss: 3.1336 - learning_rate: 0.0010
# Epoch 28/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 308ms/step - accuracy: 0.5302 - loss: 1.3442 - val_accuracy: 0.2609 - val_loss: 26.5283 - learning_rate: 0.0010
# Epoch 29/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 322ms/step - accuracy: 0.5481 - loss: 1.2699 - val_accuracy: 0.2352 - val_loss: 5.8283 - learning_rate: 0.0010
# Epoch 30/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 40s 311ms/step - accuracy: 0.5869 - loss: 1.1406 - val_accuracy: 0.5178 - val_loss: 2.2861 - learning_rate: 0.0010
# Epoch 31/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 323ms/step - accuracy: 0.6458 - loss: 1.0060 - val_accuracy: 0.4032 - val_loss: 2.1707 - learning_rate: 5.0000e-04
# Epoch 32/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 323ms/step - accuracy: 0.6443 - loss: 0.9592 - val_accuracy: 0.5296 - val_loss: 1.3630 - learning_rate: 5.0000e-04
# Epoch 33/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 331ms/step - accuracy: 0.6268 - loss: 0.9864 - val_accuracy: 0.6008 - val_loss: 1.0141 - learning_rate: 5.0000e-04
# Epoch 34/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 329ms/step - accuracy: 0.6574 - loss: 0.9212 - val_accuracy: 0.6621 - val_loss: 0.8282 - learning_rate: 5.0000e-04
# Epoch 35/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 309ms/step - accuracy: 0.6592 - loss: 0.8786 - val_accuracy: 0.2352 - val_loss: 3.3886 - learning_rate: 5.0000e-04
# Epoch 36/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 325ms/step - accuracy: 0.6292 - loss: 1.0088 - val_accuracy: 0.6008 - val_loss: 2.3464 - learning_rate: 5.0000e-04
# Epoch 37/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 307ms/step - accuracy: 0.6182 - loss: 0.9644 - val_accuracy: 0.6265 - val_loss: 0.9754 - learning_rate: 5.0000e-04
# Epoch 38/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 322ms/step - accuracy: 0.6581 - loss: 0.9023 - val_accuracy: 0.6265 - val_loss: 1.0153 - learning_rate: 5.0000e-04
# Epoch 39/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 314ms/step - accuracy: 0.6778 - loss: 0.8493 - val_accuracy: 0.5810 - val_loss: 1.0590 - learning_rate: 5.0000e-04
# Epoch 40/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 319ms/step - accuracy: 0.6806 - loss: 0.8697 - val_accuracy: 0.6779 - val_loss: 0.9299 - learning_rate: 5.0000e-04
# Epoch 41/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 326ms/step - accuracy: 0.7139 - loss: 0.7451 - val_accuracy: 0.6403 - val_loss: 0.9425 - learning_rate: 5.0000e-04
# Epoch 42/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 326ms/step - accuracy: 0.7112 - loss: 0.7706 - val_accuracy: 0.7036 - val_loss: 0.7898 - learning_rate: 5.0000e-04
# Epoch 43/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 325ms/step - accuracy: 0.6924 - loss: 0.7908 - val_accuracy: 0.6502 - val_loss: 0.9486 - learning_rate: 5.0000e-04
# Epoch 44/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 324ms/step - accuracy: 0.7064 - loss: 0.7940 - val_accuracy: 0.6186 - val_loss: 1.1081 - learning_rate: 5.0000e-04
# Epoch 45/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 321ms/step - accuracy: 0.7208 - loss: 0.7135 - val_accuracy: 0.6285 - val_loss: 1.0128 - learning_rate: 5.0000e-04
# Epoch 46/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 324ms/step - accuracy: 0.7209 - loss: 0.7161 - val_accuracy: 0.6680 - val_loss: 0.9607 - learning_rate: 5.0000e-04
# Epoch 47/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 313ms/step - accuracy: 0.7273 - loss: 0.7215 - val_accuracy: 0.6897 - val_loss: 0.8353 - learning_rate: 5.0000e-04
# Epoch 48/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 322ms/step - accuracy: 0.7212 - loss: 0.7446 - val_accuracy: 0.6067 - val_loss: 2.0154 - learning_rate: 5.0000e-04
# Epoch 49/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 323ms/step - accuracy: 0.7649 - loss: 0.6267 - val_accuracy: 0.5514 - val_loss: 1.8061 - learning_rate: 5.0000e-04
# Epoch 50/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 327ms/step - accuracy: 0.7524 - loss: 0.6352 - val_accuracy: 0.5889 - val_loss: 3.8794 - learning_rate: 5.0000e-04
# Epoch 51/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 309ms/step - accuracy: 0.7503 - loss: 0.6529 - val_accuracy: 0.4526 - val_loss: 3.2978 - learning_rate: 5.0000e-04
# Epoch 52/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 328ms/step - accuracy: 0.7563 - loss: 0.6221 - val_accuracy: 0.6897 - val_loss: 0.9612 - learning_rate: 5.0000e-04
# Epoch 53/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 313ms/step - accuracy: 0.7431 - loss: 0.6463 - val_accuracy: 0.6008 - val_loss: 1.5750 - learning_rate: 5.0000e-04
# Epoch 54/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 316ms/step - accuracy: 0.7478 - loss: 0.6512 - val_accuracy: 0.5455 - val_loss: 1.6417 - learning_rate: 5.0000e-04
# Epoch 55/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 332ms/step - accuracy: 0.7679 - loss: 0.6100 - val_accuracy: 0.5514 - val_loss: 1.3739 - learning_rate: 5.0000e-04
# Epoch 56/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 40s 317ms/step - accuracy: 0.7669 - loss: 0.6251 - val_accuracy: 0.5336 - val_loss: 1.6741 - learning_rate: 5.0000e-04
# Epoch 57/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 310ms/step - accuracy: 0.7509 - loss: 0.6208 - val_accuracy: 0.5692 - val_loss: 1.2775 - learning_rate: 5.0000e-04
# Epoch 58/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 22s 335ms/step - accuracy: 0.7746 - loss: 0.5910 - val_accuracy: 0.6324 - val_loss: 1.1212 - learning_rate: 2.5000e-04
# Epoch 59/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 313ms/step - accuracy: 0.8216 - loss: 0.4700 - val_accuracy: 0.6126 - val_loss: 1.1546 - learning_rate: 2.5000e-04
# Epoch 60/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 322ms/step - accuracy: 0.8288 - loss: 0.4750 - val_accuracy: 0.5830 - val_loss: 1.4199 - learning_rate: 2.5000e-04
# Epoch 61/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 40s 309ms/step - accuracy: 0.8186 - loss: 0.4779 - val_accuracy: 0.7134 - val_loss: 0.8127 - learning_rate: 2.5000e-04
# Epoch 62/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 324ms/step - accuracy: 0.8277 - loss: 0.4495 - val_accuracy: 0.6581 - val_loss: 1.3067 - learning_rate: 2.5000e-04
# Epoch 63/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 318ms/step - accuracy: 0.8173 - loss: 0.4743 - val_accuracy: 0.7628 - val_loss: 0.7110 - learning_rate: 2.5000e-04
# Epoch 64/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 321ms/step - accuracy: 0.8520 - loss: 0.3765 - val_accuracy: 0.5711 - val_loss: 2.0423 - learning_rate: 2.5000e-04
# Epoch 65/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 311ms/step - accuracy: 0.8329 - loss: 0.4238 - val_accuracy: 0.6561 - val_loss: 1.0785 - learning_rate: 2.5000e-04
# Epoch 66/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 319ms/step - accuracy: 0.8380 - loss: 0.3965 - val_accuracy: 0.7332 - val_loss: 0.8197 - learning_rate: 2.5000e-04
# Epoch 67/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 323ms/step - accuracy: 0.8437 - loss: 0.4115 - val_accuracy: 0.6976 - val_loss: 1.0708 - learning_rate: 2.5000e-04
# Epoch 68/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 319ms/step - accuracy: 0.8624 - loss: 0.3315 - val_accuracy: 0.6858 - val_loss: 1.0280 - learning_rate: 2.5000e-04
# Epoch 69/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 316ms/step - accuracy: 0.8383 - loss: 0.4043 - val_accuracy: 0.7352 - val_loss: 0.8438 - learning_rate: 2.5000e-04
# Epoch 70/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 315ms/step - accuracy: 0.8562 - loss: 0.3748 - val_accuracy: 0.7055 - val_loss: 0.8708 - learning_rate: 2.5000e-04
# Epoch 71/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 312ms/step - accuracy: 0.8488 - loss: 0.3784 - val_accuracy: 0.7332 - val_loss: 0.7961 - learning_rate: 2.5000e-04
# Epoch 72/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 331ms/step - accuracy: 0.8509 - loss: 0.3678 - val_accuracy: 0.7806 - val_loss: 0.6375 - learning_rate: 2.5000e-04
# Epoch 73/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 310ms/step - accuracy: 0.8710 - loss: 0.3313 - val_accuracy: 0.7510 - val_loss: 0.8148 - learning_rate: 2.5000e-04
# Epoch 74/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 324ms/step - accuracy: 0.8732 - loss: 0.3207 - val_accuracy: 0.6561 - val_loss: 1.1322 - learning_rate: 2.5000e-04
# Epoch 75/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 40s 312ms/step - accuracy: 0.8865 - loss: 0.3213 - val_accuracy: 0.5593 - val_loss: 1.9612 - learning_rate: 2.5000e-04
# Epoch 76/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 322ms/step - accuracy: 0.8479 - loss: 0.3657 - val_accuracy: 0.6285 - val_loss: 2.1165 - learning_rate: 2.5000e-04
# Epoch 77/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 42s 337ms/step - accuracy: 0.8663 - loss: 0.3224 - val_accuracy: 0.6660 - val_loss: 1.2986 - learning_rate: 2.5000e-04
# Epoch 78/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 40s 318ms/step - accuracy: 0.8651 - loss: 0.3194 - val_accuracy: 0.4881 - val_loss: 3.8546 - learning_rate: 2.5000e-04
# Epoch 79/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 323ms/step - accuracy: 0.8899 - loss: 0.2685 - val_accuracy: 0.7174 - val_loss: 0.8484 - learning_rate: 2.5000e-04
# Epoch 80/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 42s 332ms/step - accuracy: 0.9018 - loss: 0.2547 - val_accuracy: 0.6008 - val_loss: 1.7551 - learning_rate: 2.5000e-04
# Epoch 81/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 40s 315ms/step - accuracy: 0.8800 - loss: 0.2718 - val_accuracy: 0.7431 - val_loss: 0.8858 - learning_rate: 2.5000e-04
# Epoch 82/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 320ms/step - accuracy: 0.8824 - loss: 0.2857 - val_accuracy: 0.7767 - val_loss: 0.6601 - learning_rate: 2.5000e-04
# Epoch 83/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 313ms/step - accuracy: 0.8893 - loss: 0.2660 - val_accuracy: 0.7727 - val_loss: 0.9973 - learning_rate: 2.5000e-04
# Epoch 84/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 328ms/step - accuracy: 0.9026 - loss: 0.2507 - val_accuracy: 0.7727 - val_loss: 0.7612 - learning_rate: 2.5000e-04
# Epoch 85/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 328ms/step - accuracy: 0.9050 - loss: 0.2472 - val_accuracy: 0.7945 - val_loss: 0.6912 - learning_rate: 2.5000e-04
# Epoch 86/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 316ms/step - accuracy: 0.8998 - loss: 0.2549 - val_accuracy: 0.5593 - val_loss: 2.5820 - learning_rate: 2.5000e-04
# Epoch 87/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 320ms/step - accuracy: 0.8997 - loss: 0.2325 - val_accuracy: 0.6621 - val_loss: 1.4984 - learning_rate: 2.5000e-04
# Epoch 88/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 41s 321ms/step - accuracy: 0.9205 - loss: 0.2038 - val_accuracy: 0.7885 - val_loss: 0.7629 - learning_rate: 1.2500e-04
# Epoch 89/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 40s 313ms/step - accuracy: 0.9439 - loss: 0.1588 - val_accuracy: 0.7826 - val_loss: 0.8651 - learning_rate: 1.2500e-04
# Epoch 90/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 311ms/step - accuracy: 0.9528 - loss: 0.1310 - val_accuracy: 0.8043 - val_loss: 0.8069 - learning_rate: 1.2500e-04
# Epoch 91/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 318ms/step - accuracy: 0.9418 - loss: 0.1431 - val_accuracy: 0.7925 - val_loss: 0.7876 - learning_rate: 1.2500e-04
# Epoch 92/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 323ms/step - accuracy: 0.9425 - loss: 0.1571 - val_accuracy: 0.7095 - val_loss: 1.3019 - learning_rate: 1.2500e-04
# Epoch 93/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 40s 309ms/step - accuracy: 0.9321 - loss: 0.1747 - val_accuracy: 0.6186 - val_loss: 2.0850 - learning_rate: 1.2500e-04
# Epoch 94/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 315ms/step - accuracy: 0.9516 - loss: 0.1349 - val_accuracy: 0.8063 - val_loss: 0.6902 - learning_rate: 1.2500e-04
# Epoch 95/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 323ms/step - accuracy: 0.9616 - loss: 0.1078 - val_accuracy: 0.7747 - val_loss: 0.8404 - learning_rate: 1.2500e-04
# Epoch 96/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 313ms/step - accuracy: 0.9449 - loss: 0.1402 - val_accuracy: 0.7391 - val_loss: 1.0586 - learning_rate: 1.2500e-04
# Epoch 97/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 325ms/step - accuracy: 0.9467 - loss: 0.1228 - val_accuracy: 0.8083 - val_loss: 0.7741 - learning_rate: 1.2500e-04
# Epoch 98/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 324ms/step - accuracy: 0.9540 - loss: 0.1040 - val_accuracy: 0.7688 - val_loss: 0.9163 - learning_rate: 1.2500e-04
# Epoch 99/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 25s 388ms/step - accuracy: 0.9443 - loss: 0.1477 - val_accuracy: 0.6937 - val_loss: 1.3948 - learning_rate: 1.2500e-04
# Epoch 100/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 38s 341ms/step - accuracy: 0.9426 - loss: 0.1490 - val_accuracy: 0.4130 - val_loss: 6.1098 - learning_rate: 1.2500e-04
# Restoring model weights from the end of the best epoch: 72.

# %%
plot_learning_curves(history2)

# %%
def evaluate_performance(model, val_generator, class_labels):
  true_labels = val_generator.classes
  class_labels = list(val_generator.class_indices.keys())

  predictions = model.predict(val_generator, len(val_generator))
  predicted_labels = np.argmax(predictions, axis=1)

  report = classification_report(true_labels, predicted_labels, target_names=class_labels)
  print(report)
  print('\n')

  colors=["white", "royalblue"]
  cmap_colors = LinearSegmentedColormap.from_list(None, colors)

  cm = confusion_matrix(true_labels, predicted_labels)

  plt.figure(figsize=(4,3))
  sns.heatmap(cm, annot=True, cmap=cmap_colors, xticklabels=class_labels, yticklabels=class_labels)
  plt.xlabel('Predicted Labels')
  plt.ylabel('True labels')
  plt.title('Confusion matrix')
  plt.show()

# %%
evaluate_performance(modified_ResNet50, val_generator, class_labels)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 119ms/step
#               precision    recall  f1-score   support
#
#    cardboard       0.91      0.85      0.88        81
#        glass       0.83      0.75      0.79       100
#        metal       0.73      0.70      0.71        82
#        paper       0.82      0.83      0.83       119
#      plastic       0.63      0.84      0.72        97
#        trash       1.00      0.52      0.68        27
#
#     accuracy                           0.78       506
#    macro avg       0.82      0.75      0.77       506
# weighted avg       0.80      0.78      0.78       506
